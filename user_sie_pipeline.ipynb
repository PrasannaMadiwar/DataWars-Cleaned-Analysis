# %% [markdown]
# <a href="https://colab.research.google.com/github/PrasannaMadiwar/DataWars-Cleaned-Analysis/blob/main/user_sie_pipeline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import numpy as np
import pandas as pd

# %%
test_sample = pd.DataFrame({
    'Pclass': [3, 1, 2, 3],
    'Sex': ['male', 'female', 'female', 'male'],
    'Age': [24.0, 45.0, 30.0, 18.0],
    'Siblings/Spouses Aboard': [1, 0, 2, 0],
    'Parents/Children Aboard': [0, 0, 1, 1],
    'Fare': [7.8500, 82.1708, 12.2875, 9.8417]
})

# %%
pipe = pickle.load(open('pipe.pkl','rb'))

# %%
y_pred = pipe.predict(test_sample)

# %%
y_pred
# Out:
# array([0, 1, 1, 0])

# %%
test_sample
# Out:
#    Pclass     Sex   Age  Siblings/Spouses Aboard  Parents/Children Aboard  \
# 0       3    male  24.0                        1                        0
# 1       1  female  45.0                        0                        0
# 2       2  female  30.0                        2                        1
# 3       3    male  18.0                        0                        1
#
#       Fare
# 0   7.8500
# 1  82.1708
# 2  12.2875
# 3   9.8417
