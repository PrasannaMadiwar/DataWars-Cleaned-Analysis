# %% [markdown]
# <a href="https://colab.research.google.com/github/PrasannaMadiwar/DataWars-Cleaned-Analysis/blob/main/data_collection_using_API'S2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd


url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwNmQ0MjEyNDExNjY1ZDlhNDQ0MWE1NDJjODBkMzRjOCIsIm5iZiI6MTc1MTQ4MzE3OS44Niwic3ViIjoiNjg2NTgzMmJjZDRjMTNiZmQwYWM2MWYyIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.lDajAb3bbJLG3F05OYjYQ2qHobsylzzhDU6heVoNE1I"
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/rthMuZfFv4fqEU4JVbgSW9wQ8rs.jpg","genre_ids":[28,878,12],"id":986056,"original_language":"en","original_title":"Thunderbolts*","overview":"After finding themselves ensnared in a death trap, seven disillusioned castoffs must embark on a dangerous mission that will force them to confront the darkest corners of their pasts.","popularity":649.9991,"poster_path":"/hBH50Mkcrc4m8x73CovLmY7vBx1.jpg","release_date":"2025-04-30","title":"Thunderbolts*","video":false,"vote_average":7.457,"vote_count":1325},{"adult":false,"backdrop_path":"/uIpJPDNFoeX0TVml9smPrs9KUVx.jpg","genre_ids":[27,9648],"id":574475,"original_language":"en","original_title":"Final Destination Bloodlines","overview":"Plagued by a violent recurring nightmare, college student Stefanie heads home to track down the one person who might be able to break the cycle and save her family from the grisly demise that inevitably awaits them all.","popularity":513.5195,"poster_path":"
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id','title','original_language','release_date','popularity','vote_average','vote_count']]
df.shape
# Out:
# (20, 7)

# %%
final = pd.DataFrame()

for i in range(1,501):

  url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page={}".format(i)

  headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiIwNmQ0MjEyNDExNjY1ZDlhNDQ0MWE1NDJjODBkMzRjOCIsIm5iZiI6MTc1MTQ4MzE3OS44Niwic3ViIjoiNjg2NTgzMmJjZDRjMTNiZmQwYWM2MWYyIiwic2NvcGVzIjpbImFwaV9yZWFkIl0sInZlcnNpb24iOjF9.lDajAb3bbJLG3F05OYjYQ2qHobsylzzhDU6heVoNE1I"
          }

  response = requests.get(url, headers=headers)

  d = pd.DataFrame(response.json()['results'])[['id','title','original_language','release_date','popularity','vote_average','vote_count']]

  final = pd.concat([final,d],ignore_index=True)

# %%
final.shape
# Out:
# (9998, 7)

# %%
final.head(25)
# Out:
#          id                                      title original_language  \
# 0    986056                              Thunderbolts*                en
# 1    574475               Final Destination Bloodlines                en
# 2    541671                                  Ballerina                en
# 3    552524                              Lilo & Stitch                en
# 4   1090007                                First Shift                en
# 5   1087192                   How to Train Your Dragon                en
# 6    803796                         KPop Demon Hunters                en
# 7    911430                                         F1                en
# 8   1311844                               The Twisters                en
# 9    605722                                    Distant                en
# 10  1412113                Squid Game: Making Season 2                ko
# 11  1442776                               Crazy Lizard                zh
# ...

# %%
final.to_csv('Most_popular_movies_across_world')
